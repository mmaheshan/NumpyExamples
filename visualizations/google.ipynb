# %%
import csv
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt


with open('./GOOGL.csv') as f:
    reader = csv.reader(f)
    data = list(reader)

headers = data[0]

data = data[1:]
print(headers)
# Out:
# ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Name']

# %%
data = np.array(data)
shp = data.shape
# print(data)
dates = data[:,0].astype(np.datetime64)
dates
# Out:
# array(['2006-01-03', '2006-01-04', '2006-01-05', ..., '2017-12-27',
#        '2017-12-28', '2017-12-29'], shape=(3019,), dtype='datetime64[D]')

# %%
closing_prices = data[:,4].astype(np.float32)
closing_prices

np.mean(closing_prices)
# Out:
# np.float32(428.044)

# %%
plt.plot(dates,closing_prices)
