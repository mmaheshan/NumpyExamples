# %% [markdown]
# # Some Exam Questions

# %%
import numpy as np
a = np.array([1, 2, 3, 4])
az = a.sum()
az
# Out:
# np.int64(10)

# %%
b = np.array([1, 2 , np.nan, 4])
bz = b.sum()
bz
# Out:
# np.float64(nan)
